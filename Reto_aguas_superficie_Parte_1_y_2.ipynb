# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Ciencia  y Analitica de datos**
# ###Tecnológico de Monterrey
#
# ## **Actividad RETO: Aguas superficie**

# %% [markdown]
# **Nombres y matrículas de los integrantes del equipo:**
#
# *   Elmer Ali Payró Costilla A0
# *   Maria Fernanda Prieto Vargas A01794329

# %% [markdown]
# **PRIMER ENTREGABLE: Limpieza, análisis, visualización y kmeans**

# %%
#! pip install qeds fiona geopandas xgboost gensim folium pyLDAvis descartes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import geopandas as gpd
from shapely.geometry import Point
import qeds
from sklearn.metrics import silhouette_samples
from matplotlib.ticker import FixedLocator, FixedFormatter
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate, cross_val_predict
from sklearn.dummy import DummyClassifier
from sklearn.compose import TransformedTargetRegressor
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, make_scorer, confusion_matrix, classification_report
from sklearn.model_selection import RepeatedKFold, RepeatedStratifiedKFold, validation_curve, learning_curve
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier 
import pydotplus
from IPython.display import Image
from sklearn.tree import export_graphviz
from sklearn import tree

# %%
data = pd.read_csv('datos/agua_superficiales.csv',index_col=0, encoding='latin-1')

# %%
data.head()
# Out:
#                                                       SITIO  \
# CLAVE
# DLAGU8    PRESA EL SAUCILLO 100M AGUAS ARRIBA DE LA CORTINA
# DLBAJ100                         LOS CABOS SEG 22, 2 ISA10B
# DLBAJ101                         LOS CABOS SEG 22, 1 ISA10B
# DLBAJ102                                        LOS CABOS 3
# DLBAJ103                                        LOS CABOS 1
#
#                    ORGANISMO_DE_CUENCA               ESTADO        MUNICIPIO  \
# CLAVE
# DLAGU8         LERMA SANTIAGO PACIFICO       AGUASCALIENTES  RINCON DE ROMOS
# DLBAJ100  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
# DLBAJ101  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
# DLBAJ102  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
# DLBAJ103  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
#
#                      CUENCA     CUERPO DE AGUA     TIPO     SUBTIPO  \
# CLAVE
# DLAGU8        RIO SAN PEDRO  PRESA EL SAUCILLO  LENTICO       PRESA
# DLBAJ100  SAN JOSE DEL CABO    OCEANO PACIFICO  COSTERO  OCEANO-MAR
# DLBAJ101          SAN LUCAS    OCEANO PACIFICO  COSTERO  OCEANO-MAR
# DLBAJ102          SAN LUCAS    BAHIA SAN LUCAS  COSTERO       BAHIA
# DLBAJ103          SAN LUCAS    BAHIA SAN LUCAS  COSTERO       BAHIA
#
#            LONGITUD   LATITUD  ...  CONTAMINANTES CUMPLE_CON_DBO  \
# CLAVE                          ...
# DLAGU8   -102.33911  22.24730  ...        DQO,CF,             SI
# DLBAJ100 -109.84290  22.90473  ...            NaN             ND
# DLBAJ101 -109.86442  22.89880  ...            NaN             ND
# DLBAJ102 -109.88604  22.89609  ...            NaN             ND
# DLBAJ103 -109.89657  22.87694  ...            NaN             ND
#
#          CUMPLE_CON_DQO CUMPLE_CON_SST CUMPLE_CON_CF CUMPLE_CON_E_COLI  \
# CLAVE
# DLAGU8               NO             SI            NO                SI
# DLBAJ100             ND             SI            ND                ND
# DLBAJ101             ND             SI            ND                ND
# DLBAJ102             ND             SI            ND                ND
# DLBAJ103             ND             SI            ND                ND
#
#          CUMPLE_CON_ENTEROC CUMPLE_CON_OD CUMPLE_CON_TOX    GRUPO
# CLAVE
# DLAGU8                   ND            SI             SI  LENTICO
# DLBAJ100                 SI            SI             SI  COSTERO
# DLBAJ101                 SI            SI             SI  COSTERO
# DLBAJ102                 SI            SI             SI  COSTERO
# DLBAJ103                 SI            SI             SI  COSTERO
#
# [5 rows x 54 columns]

# %%
data.describe()
# Out:
#           LONGITUD      LATITUD  PERIODO  TOX_D_48_FON_UT  \
# count  3493.000000  3493.000000   3493.0              0.0
# mean   -100.359969    21.046992   2020.0              NaN
# std       6.122773     3.893696      0.0              NaN
# min    -117.124030    14.534910   2020.0              NaN
# 25%    -103.882310    18.396070   2020.0              NaN
# 50%     -99.795530    20.148980   2020.0              NaN
# 75%     -96.860230    22.828930   2020.0              NaN
# max     -86.732150    32.706500   2020.0              NaN
#
#        CALIDAD_TOX_D_48_FON  TOX_FIS_FON_15_UT  CALIDAD_TOX_FIS_FON_15
# count                   0.0                0.0                     0.0
# mean                    NaN                NaN                     NaN
# std                     NaN                NaN                     NaN
# min                     NaN                NaN                     NaN
# 25%                     NaN                NaN                     NaN
# 50%                     NaN                NaN                     NaN
# 75%                     NaN                NaN                     NaN
# max                     NaN                NaN                     NaN

# %%
data.mean()
# Out:
# C:\Users\elmer\AppData\Local\Temp\ipykernel_17632\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# LONGITUD                  -100.359969
# LATITUD                     21.046992
# PERIODO                   2020.000000
# TOX_D_48_FON_UT                   NaN
# CALIDAD_TOX_D_48_FON              NaN
# TOX_FIS_FON_15_UT                 NaN
# CALIDAD_TOX_FIS_FON_15            NaN
# dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4141 entries, DLAGU8 to nan
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SITIO                   3493 non-null   object
#  1   ORGANISMO_DE_CUENCA     3493 non-null   object
#  2   ESTADO                  3493 non-null   object
#  3   MUNICIPIO               3493 non-null   object
#  4   CUENCA                  3492 non-null   object
#  5   CUERPO DE AGUA          3479 non-null   object
#  6   TIPO                    3493 non-null   object
#  7   SUBTIPO                 3479 non-null   object
#  8   LONGITUD                3493 non-null   float64
#  9   LATITUD                 3493 non-null   float64
#  10  PERIODO                 3493 non-null   float64
#  11  DBO_mg/L                2581 non-null   object
#  12  CALIDAD_DBO             2581 non-null   object
#  13  DQO_mg/L                2581 non-null   object
#  14  CALIDAD_DQO             2581 non-null   object
#  15  SST_mg/L                3489 non-null   object
#  16  CALIDAD_SST             3489 non-null   object
#  17  COLI_FEC_NMP_100mL      2582 non-null   object
#  18  CALIDAD_COLI_FEC        2582 non-null   object
#  19  E_COLI_NMP_100mL        2582 non-null   object
#  20  CALIDAD_E_COLI          2582 non-null   object
#  21  ENTEROC_NMP_100mL       904 non-null    object
#  22  CALIDAD_ENTEROC         904 non-null    object
#  23  OD_PORC                 1797 non-null   object
#  24  CALIDAD_OD_PORC         1797 non-null   object
#  25  OD_PORC_SUP             1619 non-null   object
#  26  CALIDAD_OD_PORC_SUP     1619 non-null   object
#  27  OD_PORC_MED             487 non-null    object
#  28  CALIDAD_OD_PORC_MED     487 non-null    object
#  29  OD_PORC_FON             946 non-null    object
#  30  CALIDAD_OD_PORC_FON     946 non-null    object
#  31  TOX_D_48_UT             1816 non-null   object
#  32  CALIDAD_TOX_D_48        1816 non-null   object
#  33  TOX_V_15_UT             1819 non-null   object
#  34  CALIDAD_TOX_V_15        1819 non-null   object
#  35  TOX_D_48_SUP_UT         762 non-null    object
#  36  CALIDAD TOX_D_48_SUP    762 non-null    object
#  37  TOX_D_48_FON_UT         0 non-null      float64
#  38  CALIDAD_TOX_D_48_FON    0 non-null      float64
#  39  TOX_FIS_SUP_15_UT       1674 non-null   object
#  40  CALIDAD_TOX_FIS_SUP_15  1674 non-null   object
#  41  TOX_FIS_FON_15_UT       0 non-null      float64
#  42  CALIDAD_TOX_FIS_FON_15  0 non-null      float64
#  43  SEMAFORO                3493 non-null   object
#  44  CONTAMINANTES           2226 non-null   object
#  45  CUMPLE_CON_DBO          3493 non-null   object
#  46  CUMPLE_CON_DQO          3493 non-null   object
#  47  CUMPLE_CON_SST          3493 non-null   object
#  48  CUMPLE_CON_CF           3493 non-null   object
#  49  CUMPLE_CON_E_COLI       3493 non-null   object
#  50  CUMPLE_CON_ENTEROC      3493 non-null   object
#  51  CUMPLE_CON_OD           3493 non-null   object
#  52  CUMPLE_CON_TOX          3493 non-null   object
#  53  GRUPO                   3493 non-null   object
# dtypes: float64(7), object(47)
# memory usage: 1.7+ MB

# %%
data.isna().sum() / np.max(data.count()) * 100
# Out:
# SITIO                      18.551388
# ORGANISMO_DE_CUENCA        18.551388
# ESTADO                     18.551388
# MUNICIPIO                  18.551388
# CUENCA                     18.580017
# CUERPO DE AGUA             18.952190
# TIPO                       18.551388
# SUBTIPO                    18.952190
# LONGITUD                   18.551388
# LATITUD                    18.551388
# PERIODO                    18.551388
# DBO_mg/L                   44.660750
# CALIDAD_DBO                44.660750
# DQO_mg/L                   44.660750
# CALIDAD_DQO                44.660750
# SST_mg/L                   18.665903
# CALIDAD_SST                18.665903
# COLI_FEC_NMP_100mL         44.632121
# CALIDAD_COLI_FEC           44.632121
# E_COLI_NMP_100mL           44.632121
# CALIDAD_E_COLI             44.632121
# ENTEROC_NMP_100mL          92.671056
# CALIDAD_ENTEROC            92.671056
# OD_PORC                    67.105640
# CALIDAD_OD_PORC            67.105640
# OD_PORC_SUP                72.201546
# CALIDAD_OD_PORC_SUP        72.201546
# OD_PORC_MED               104.609218
# CALIDAD_OD_PORC_MED       104.609218
# OD_PORC_FON                91.468652
# CALIDAD_OD_PORC_FON        91.468652
# TOX_D_48_UT                66.561695
# CALIDAD_TOX_D_48           66.561695
# TOX_V_15_UT                66.475809
# CALIDAD_TOX_V_15           66.475809
# TOX_D_48_SUP_UT            96.736330
# CALIDAD TOX_D_48_SUP       96.736330
# TOX_D_48_FON_UT           118.551388
# CALIDAD_TOX_D_48_FON      118.551388
# TOX_FIS_SUP_15_UT          70.626968
# CALIDAD_TOX_FIS_SUP_15     70.626968
# TOX_FIS_FON_15_UT         118.551388
# CALIDAD_TOX_FIS_FON_15    118.551388
# SEMAFORO                   18.551388
# CONTAMINANTES              54.823934
# CUMPLE_CON_DBO             18.551388
# CUMPLE_CON_DQO             18.551388
# CUMPLE_CON_SST             18.551388
# CUMPLE_CON_CF              18.551388
# CUMPLE_CON_E_COLI          18.551388
# CUMPLE_CON_ENTEROC         18.551388
# CUMPLE_CON_OD              18.551388
# CUMPLE_CON_TOX             18.551388
# GRUPO                      18.551388
# dtype: float64

# %%
data.columns
# Out:
# Index(['SITIO', 'ORGANISMO_DE_CUENCA', 'ESTADO', 'MUNICIPIO', 'CUENCA',
#        'CUERPO DE AGUA', 'TIPO', 'SUBTIPO', 'LONGITUD', 'LATITUD', 'PERIODO',
#        'DBO_mg/L', 'CALIDAD_DBO', 'DQO_mg/L', 'CALIDAD_DQO', 'SST_mg/L',
#        'CALIDAD_SST', 'COLI_FEC_NMP_100mL', 'CALIDAD_COLI_FEC',
#        'E_COLI_NMP_100mL', 'CALIDAD_E_COLI', 'ENTEROC_NMP_100mL',
#        'CALIDAD_ENTEROC', 'OD_PORC', 'CALIDAD_OD_PORC', 'OD_PORC_SUP',
#        'CALIDAD_OD_PORC_SUP', 'OD_PORC_MED', 'CALIDAD_OD_PORC_MED',
#        'OD_PORC_FON', 'CALIDAD_OD_PORC_FON', 'TOX_D_48_UT', 'CALIDAD_TOX_D_48',
#        'TOX_V_15_UT', 'CALIDAD_TOX_V_15', 'TOX_D_48_SUP_UT',
#        'CALIDAD TOX_D_48_SUP', 'TOX_D_48_FON_UT', 'CALIDAD_TOX_D_48_FON',
#        'TOX_FIS_SUP_15_UT', 'CALIDAD_TOX_FIS_SUP_15', 'TOX_FIS_FON_15_UT',
#        'CALIDAD_TOX_FIS_FON_15', 'SEMAFORO', 'CONTAMINANTES', 'CUMPLE_CON_DBO',
#        'CUMPLE_CON_DQO', 'CUMPLE_CON_SST', 'CUMPLE_CON_CF',
#        'CUMPLE_CON_E_COLI', 'CUMPLE_CON_ENTEROC', 'CUMPLE_CON_OD',
#        'CUMPLE_CON_TOX', 'GRUPO'],
#       dtype='object')

# %%
data.drop_duplicates(inplace=True)
print (f'tamaño de las filas repeditas: {data.shape}')
# Out:
# tamaño de las filas repeditas: (3494, 54)

# %%
data.drop(['PERIODO','TOX_D_48_FON_UT','CALIDAD_TOX_D_48_FON','TOX_FIS_FON_15_UT','CALIDAD_TOX_FIS_FON_15'],  axis = 'columns', inplace=True)
data.head (5)
# Out:
#                                                       SITIO  \
# CLAVE
# DLAGU8    PRESA EL SAUCILLO 100M AGUAS ARRIBA DE LA CORTINA
# DLBAJ100                         LOS CABOS SEG 22, 2 ISA10B
# DLBAJ101                         LOS CABOS SEG 22, 1 ISA10B
# DLBAJ102                                        LOS CABOS 3
# DLBAJ103                                        LOS CABOS 1
#
#                    ORGANISMO_DE_CUENCA               ESTADO        MUNICIPIO  \
# CLAVE
# DLAGU8         LERMA SANTIAGO PACIFICO       AGUASCALIENTES  RINCON DE ROMOS
# DLBAJ100  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
# DLBAJ101  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
# DLBAJ102  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
# DLBAJ103  PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR        LOS CABOS
#
#                      CUENCA     CUERPO DE AGUA     TIPO     SUBTIPO  \
# CLAVE
# DLAGU8        RIO SAN PEDRO  PRESA EL SAUCILLO  LENTICO       PRESA
# DLBAJ100  SAN JOSE DEL CABO    OCEANO PACIFICO  COSTERO  OCEANO-MAR
# DLBAJ101          SAN LUCAS    OCEANO PACIFICO  COSTERO  OCEANO-MAR
# DLBAJ102          SAN LUCAS    BAHIA SAN LUCAS  COSTERO       BAHIA
# DLBAJ103          SAN LUCAS    BAHIA SAN LUCAS  COSTERO       BAHIA
#
#            LONGITUD   LATITUD  ... CONTAMINANTES CUMPLE_CON_DBO  \
# CLAVE                          ...
# DLAGU8   -102.33911  22.24730  ...       DQO,CF,             SI
# DLBAJ100 -109.84290  22.90473  ...           NaN             ND
# DLBAJ101 -109.86442  22.89880  ...           NaN             ND
# DLBAJ102 -109.88604  22.89609  ...           NaN             ND
# DLBAJ103 -109.89657  22.87694  ...           NaN             ND
#
#          CUMPLE_CON_DQO CUMPLE_CON_SST CUMPLE_CON_CF CUMPLE_CON_E_COLI  \
# CLAVE
# DLAGU8               NO             SI            NO                SI
# DLBAJ100             ND             SI            ND                ND
# DLBAJ101             ND             SI            ND                ND
# DLBAJ102             ND             SI            ND                ND
# DLBAJ103             ND             SI            ND                ND
#
#          CUMPLE_CON_ENTEROC CUMPLE_CON_OD CUMPLE_CON_TOX    GRUPO
# CLAVE
# DLAGU8                   ND            SI             SI  LENTICO
# DLBAJ100                 SI            SI             SI  COSTERO
# DLBAJ101                 SI            SI             SI  COSTERO
# DLBAJ102                 SI            SI             SI  COSTERO
# DLBAJ103                 SI            SI             SI  COSTERO
#
# [5 rows x 49 columns]

# %%
data.describe()
# Out:
#           LONGITUD      LATITUD
# count  3493.000000  3493.000000
# mean   -100.359969    21.046992
# std       6.122773     3.893696
# min    -117.124030    14.534910
# 25%    -103.882310    18.396070
# 50%     -99.795530    20.148980
# 75%     -96.860230    22.828930
# max     -86.732150    32.706500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3494 entries, DLAGU8 to nan
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SITIO                   3493 non-null   object
#  1   ORGANISMO_DE_CUENCA     3493 non-null   object
#  2   ESTADO                  3493 non-null   object
#  3   MUNICIPIO               3493 non-null   object
#  4   CUENCA                  3492 non-null   object
#  5   CUERPO DE AGUA          3479 non-null   object
#  6   TIPO                    3493 non-null   object
#  7   SUBTIPO                 3479 non-null   object
#  8   LONGITUD                3493 non-null   float64
#  9   LATITUD                 3493 non-null   float64
#  10  DBO_mg/L                2581 non-null   object
#  11  CALIDAD_DBO             2581 non-null   object
#  12  DQO_mg/L                2581 non-null   object
#  13  CALIDAD_DQO             2581 non-null   object
#  14  SST_mg/L                3489 non-null   object
#  15  CALIDAD_SST             3489 non-null   object
#  16  COLI_FEC_NMP_100mL      2582 non-null   object
#  17  CALIDAD_COLI_FEC        2582 non-null   object
#  18  E_COLI_NMP_100mL        2582 non-null   object
#  19  CALIDAD_E_COLI          2582 non-null   object
#  20  ENTEROC_NMP_100mL       904 non-null    object
#  21  CALIDAD_ENTEROC         904 non-null    object
#  22  OD_PORC                 1797 non-null   object
#  23  CALIDAD_OD_PORC         1797 non-null   object
#  24  OD_PORC_SUP             1619 non-null   object
#  25  CALIDAD_OD_PORC_SUP     1619 non-null   object
#  26  OD_PORC_MED             487 non-null    object
#  27  CALIDAD_OD_PORC_MED     487 non-null    object
#  28  OD_PORC_FON             946 non-null    object
#  29  CALIDAD_OD_PORC_FON     946 non-null    object
#  30  TOX_D_48_UT             1816 non-null   object
#  31  CALIDAD_TOX_D_48        1816 non-null   object
#  32  TOX_V_15_UT             1819 non-null   object
#  33  CALIDAD_TOX_V_15        1819 non-null   object
#  34  TOX_D_48_SUP_UT         762 non-null    object
#  35  CALIDAD TOX_D_48_SUP    762 non-null    object
#  36  TOX_FIS_SUP_15_UT       1674 non-null   object
#  37  CALIDAD_TOX_FIS_SUP_15  1674 non-null   object
#  38  SEMAFORO                3493 non-null   object
#  39  CONTAMINANTES           2226 non-null   object
#  40  CUMPLE_CON_DBO          3493 non-null   object
#  41  CUMPLE_CON_DQO          3493 non-null   object
#  42  CUMPLE_CON_SST          3493 non-null   object
#  43  CUMPLE_CON_CF           3493 non-null   object
#  44  CUMPLE_CON_E_COLI       3493 non-null   object
#  45  CUMPLE_CON_ENTEROC      3493 non-null   object
#  46  CUMPLE_CON_OD           3493 non-null   object
#  47  CUMPLE_CON_TOX          3493 non-null   object
#  48  GRUPO                   3493 non-null   object
# dtypes: float64(2), object(47)
# memory usage: 1.3+ MB

# %%
missing_data = data.isnull()
missing_data.head(5)
# Out:
#           SITIO  ORGANISMO_DE_CUENCA  ESTADO  MUNICIPIO  CUENCA  \
# CLAVE
# DLAGU8    False                False   False      False   False
# DLBAJ100  False                False   False      False   False
# DLBAJ101  False                False   False      False   False
# DLBAJ102  False                False   False      False   False
# DLBAJ103  False                False   False      False   False
#
#           CUERPO DE AGUA   TIPO  SUBTIPO  LONGITUD  LATITUD  ...  \
# CLAVE                                                        ...
# DLAGU8             False  False    False     False    False  ...
# DLBAJ100           False  False    False     False    False  ...
# DLBAJ101           False  False    False     False    False  ...
# DLBAJ102           False  False    False     False    False  ...
# DLBAJ103           False  False    False     False    False  ...
#
#           CONTAMINANTES  CUMPLE_CON_DBO  CUMPLE_CON_DQO  CUMPLE_CON_SST  \
# CLAVE
# DLAGU8            False           False           False           False
# DLBAJ100           True           False           False           False
# DLBAJ101           True           False           False           False
# DLBAJ102           True           False           False           False
# DLBAJ103           True           False           False           False
#
#           CUMPLE_CON_CF  CUMPLE_CON_E_COLI  CUMPLE_CON_ENTEROC  CUMPLE_CON_OD  \
# CLAVE
# DLAGU8            False              False               False          False
# DLBAJ100          False              False               False          False
# DLBAJ101          False              False               False          False
# DLBAJ102          False              False               False          False
# DLBAJ103          False              False               False          False
#
#           CUMPLE_CON_TOX  GRUPO
# CLAVE
# DLAGU8             False  False
# DLBAJ100           False  False
# DLBAJ101           False  False
# DLBAJ102           False  False
# DLBAJ103           False  False
#
# [5 rows x 49 columns]

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# SITIO
# False    3493
# True        1
# Name: SITIO, dtype: int64
#
# ORGANISMO_DE_CUENCA
# False    3493
# True        1
# Name: ORGANISMO_DE_CUENCA, dtype: int64
#
# ESTADO
# False    3493
# True        1
# Name: ESTADO, dtype: int64
#
# MUNICIPIO
# False    3493
# True        1
# Name: MUNICIPIO, dtype: int64
#
# CUENCA
# False    3492
# True        2
# Name: CUENCA, dtype: int64
#
# CUERPO DE AGUA
# False    3479
# True       15
# Name: CUERPO DE AGUA, dtype: int64
#
# TIPO
# False    3493
# True        1
# Name: TIPO, dtype: int64
#
# SUBTIPO
# False    3479
# True       15
# Name: SUBTIPO, dtype: int64
#
# LONGITUD
# False    3493
# True        1
# Name: LONGITUD, dtype: int64
#
# LATITUD
# False    3493
# True        1
# Name: LATITUD, dtype: int64
#
# DBO_mg/L
# False    2581
# True      913
# Name: DBO_mg/L, dtype: int64
#
# CALIDAD_DBO
# False    2581
# True      913
# Name: CALIDAD_DBO, dtype: int64
#
# DQO_mg/L
# False    2581
# True      913
# Name: DQO_mg/L, dtype: int64
#
# CALIDAD_DQO
# False    2581
# True      913
# Name: CALIDAD_DQO, dtype: int64
#
# SST_mg/L
# False    3489
# True        5
# Name: SST_mg/L, dtype: int64
#
# CALIDAD_SST
# False    3489
# True        5
# Name: CALIDAD_SST, dtype: int64
#
# COLI_FEC_NMP_100mL
# False    2582
# True      912
# Name: COLI_FEC_NMP_100mL, dtype: int64
#
# CALIDAD_COLI_FEC
# False    2582
# True      912
# Name: CALIDAD_COLI_FEC, dtype: int64
#
# E_COLI_NMP_100mL
# False    2582
# True      912
# Name: E_COLI_NMP_100mL, dtype: int64
#
# CALIDAD_E_COLI
# False    2582
# True      912
# Name: CALIDAD_E_COLI, dtype: int64
#
# ENTEROC_NMP_100mL
# True     2590
# False     904
# Name: ENTEROC_NMP_100mL, dtype: int64
#
# CALIDAD_ENTEROC
# True     2590
# False     904
# Name: CALIDAD_ENTEROC, dtype: int64
#
# OD_PORC
# False    1797
# True     1697
# Name: OD_PORC, dtype: int64
#
# CALIDAD_OD_PORC
# False    1797
# True     1697
# Name: CALIDAD_OD_PORC, dtype: int64
#
# OD_PORC_SUP
# True     1875
# False    1619
# Name: OD_PORC_SUP, dtype: int64
#
# CALIDAD_OD_PORC_SUP
# True     1875
# False    1619
# Name: CALIDAD_OD_PORC_SUP, dtype: int64
#
# OD_PORC_MED
# True     3007
# False     487
# Name: OD_PORC_MED, dtype: int64
#
# CALIDAD_OD_PORC_MED
# True     3007
# False     487
# Name: CALIDAD_OD_PORC_MED, dtype: int64
#
# OD_PORC_FON
# True     2548
# False     946
# Name: OD_PORC_FON, dtype: int64
#
# CALIDAD_OD_PORC_FON
# True     2548
# False     946
# Name: CALIDAD_OD_PORC_FON, dtype: int64
#
# TOX_D_48_UT
# False    1816
# True     1678
# Name: TOX_D_48_UT, dtype: int64
#
# CALIDAD_TOX_D_48
# False    1816
# True     1678
# Name: CALIDAD_TOX_D_48, dtype: int64
#
# TOX_V_15_UT
# False    1819
# True     1675
# Name: TOX_V_15_UT, dtype: int64
#
# CALIDAD_TOX_V_15
# False    1819
# True     1675
# Name: CALIDAD_TOX_V_15, dtype: int64
#
# TOX_D_48_SUP_UT
# True     2732
# False     762
# Name: TOX_D_48_SUP_UT, dtype: int64
#
# CALIDAD TOX_D_48_SUP
# True     2732
# False     762
# Name: CALIDAD TOX_D_48_SUP, dtype: int64
#
# TOX_FIS_SUP_15_UT
# True     1820
# False    1674
# Name: TOX_FIS_SUP_15_UT, dtype: int64
#
# CALIDAD_TOX_FIS_SUP_15
# True     1820
# False    1674
# Name: CALIDAD_TOX_FIS_SUP_15, dtype: int64
#
# SEMAFORO
# False    3493
# True        1
# Name: SEMAFORO, dtype: int64
#
# CONTAMINANTES
# False    2226
# True     1268
# Name: CONTAMINANTES, dtype: int64
#
# CUMPLE_CON_DBO
# False    3493
# True        1
# Name: CUMPLE_CON_DBO, dtype: int64
#
# CUMPLE_CON_DQO
# False    3493
# True        1
# Name: CUMPLE_CON_DQO, dtype: int64
#
# CUMPLE_CON_SST
# False    3493
# True        1
# Name: CUMPLE_CON_SST, dtype: int64
#
# CUMPLE_CON_CF
# False    3493
# True        1
# Name: CUMPLE_CON_CF, dtype: int64
#
# CUMPLE_CON_E_COLI
# False    3493
# True        1
# Name: CUMPLE_CON_E_COLI, dtype: int64
#
# CUMPLE_CON_ENTEROC
# False    3493
# True        1
# Name: CUMPLE_CON_ENTEROC, dtype: int64
#
# CUMPLE_CON_OD
# False    3493
# True        1
# Name: CUMPLE_CON_OD, dtype: int64
#
# CUMPLE_CON_TOX
# False    3493
# True        1
# Name: CUMPLE_CON_TOX, dtype: int64
#
# GRUPO
# False    3493
# True        1
# Name: GRUPO, dtype: int64

# %%
# Reemplazando notación matemática y transformando a tipo double
numeric_features = ['TOX_D_48_UT','TOX_V_15_UT','TOX_D_48_SUP_UT','TOX_FIS_SUP_15_UT','DBO_mg/L','DQO_mg/L','SST_mg/L','OD_PORC','OD_PORC_SUP','OD_PORC_MED','OD_PORC_FON','COLI_FEC_NMP_100mL','E_COLI_NMP_100mL','ENTEROC_NMP_100mL']

data[['TOX_D_48_UT','TOX_V_15_UT','TOX_D_48_SUP_UT','TOX_FIS_SUP_15_UT']] = data[['TOX_D_48_UT','TOX_V_15_UT','TOX_D_48_SUP_UT','TOX_FIS_SUP_15_UT']].replace('<1','0.5')

data['DBO_mg/L'] = data['DBO_mg/L'].replace('<2','1')

data[['DQO_mg/L','SST_mg/L','OD_PORC','OD_PORC_SUP','OD_PORC_MED','OD_PORC_FON']] = data[['DQO_mg/L','SST_mg/L','OD_PORC','OD_PORC_SUP','OD_PORC_MED','OD_PORC_FON']].replace('<10','9')

data[['COLI_FEC_NMP_100mL','E_COLI_NMP_100mL','ENTEROC_NMP_100mL']] = data[['COLI_FEC_NMP_100mL','E_COLI_NMP_100mL','ENTEROC_NMP_100mL']].replace('<3','2')


data[numeric_features] = data[numeric_features].astype('double')

# %%
data['DBO_mg/L'].isna().sum() # Aun quedan nulls pero debe ser asi para no interferir con los otros valores
# Out:
# 913

# %%
data['DBO_mg/L'].count()
# Out:
# 2581

# %%
# Revisando la cantidad de datos faltantes
data.isna().sum() / np.max(data.count()) * 100
# Out:
# SITIO                      0.028629
# ORGANISMO_DE_CUENCA        0.028629
# ESTADO                     0.028629
# MUNICIPIO                  0.028629
# CUENCA                     0.057257
# CUERPO DE AGUA             0.429430
# TIPO                       0.028629
# SUBTIPO                    0.429430
# LONGITUD                   0.028629
# LATITUD                    0.028629
# DBO_mg/L                  26.137990
# CALIDAD_DBO               26.137990
# DQO_mg/L                  26.137990
# CALIDAD_DQO               26.137990
# SST_mg/L                   0.143143
# CALIDAD_SST                0.143143
# COLI_FEC_NMP_100mL        26.109362
# CALIDAD_COLI_FEC          26.109362
# E_COLI_NMP_100mL          26.109362
# CALIDAD_E_COLI            26.109362
# ENTEROC_NMP_100mL         74.148297
# CALIDAD_ENTEROC           74.148297
# OD_PORC                   48.582880
# CALIDAD_OD_PORC           48.582880
# OD_PORC_SUP               53.678786
# CALIDAD_OD_PORC_SUP       53.678786
# OD_PORC_MED               86.086459
# CALIDAD_OD_PORC_MED       86.086459
# OD_PORC_FON               72.945892
# CALIDAD_OD_PORC_FON       72.945892
# TOX_D_48_UT               48.038935
# CALIDAD_TOX_D_48          48.038935
# TOX_V_15_UT               47.953049
# CALIDAD_TOX_V_15          47.953049
# TOX_D_48_SUP_UT           78.213570
# CALIDAD TOX_D_48_SUP      78.213570
# TOX_FIS_SUP_15_UT         52.104208
# CALIDAD_TOX_FIS_SUP_15    52.104208
# SEMAFORO                   0.028629
# CONTAMINANTES             36.301174
# CUMPLE_CON_DBO             0.028629
# CUMPLE_CON_DQO             0.028629
# CUMPLE_CON_SST             0.028629
# CUMPLE_CON_CF              0.028629
# CUMPLE_CON_E_COLI          0.028629
# CUMPLE_CON_ENTEROC         0.028629
# CUMPLE_CON_OD              0.028629
# CUMPLE_CON_TOX             0.028629
# GRUPO                      0.028629
# dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3494 entries, DLAGU8 to nan
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SITIO                   3493 non-null   object
#  1   ORGANISMO_DE_CUENCA     3493 non-null   object
#  2   ESTADO                  3493 non-null   object
#  3   MUNICIPIO               3493 non-null   object
#  4   CUENCA                  3492 non-null   object
#  5   CUERPO DE AGUA          3479 non-null   object
#  6   TIPO                    3493 non-null   object
#  7   SUBTIPO                 3479 non-null   object
#  8   LONGITUD                3493 non-null   float64
#  9   LATITUD                 3493 non-null   float64
#  10  DBO_mg/L                2581 non-null   float64
#  11  CALIDAD_DBO             2581 non-null   object
#  12  DQO_mg/L                2581 non-null   float64
#  13  CALIDAD_DQO             2581 non-null   object
#  14  SST_mg/L                3489 non-null   float64
#  15  CALIDAD_SST             3489 non-null   object
#  16  COLI_FEC_NMP_100mL      2582 non-null   float64
#  17  CALIDAD_COLI_FEC        2582 non-null   object
#  18  E_COLI_NMP_100mL        2582 non-null   float64
#  19  CALIDAD_E_COLI          2582 non-null   object
#  20  ENTEROC_NMP_100mL       904 non-null    float64
#  21  CALIDAD_ENTEROC         904 non-null    object
#  22  OD_PORC                 1797 non-null   float64
#  23  CALIDAD_OD_PORC         1797 non-null   object
#  24  OD_PORC_SUP             1619 non-null   float64
#  25  CALIDAD_OD_PORC_SUP     1619 non-null   object
#  26  OD_PORC_MED             487 non-null    float64
#  27  CALIDAD_OD_PORC_MED     487 non-null    object
#  28  OD_PORC_FON             946 non-null    float64
#  29  CALIDAD_OD_PORC_FON     946 non-null    object
#  30  TOX_D_48_UT             1816 non-null   float64
#  31  CALIDAD_TOX_D_48        1816 non-null   object
#  32  TOX_V_15_UT             1819 non-null   float64
#  33  CALIDAD_TOX_V_15        1819 non-null   object
#  34  TOX_D_48_SUP_UT         762 non-null    float64
#  35  CALIDAD TOX_D_48_SUP    762 non-null    object
#  36  TOX_FIS_SUP_15_UT       1674 non-null   float64
#  37  CALIDAD_TOX_FIS_SUP_15  1674 non-null   object
#  38  SEMAFORO                3493 non-null   object
#  39  CONTAMINANTES           2226 non-null   object
#  40  CUMPLE_CON_DBO          3493 non-null   object
#  41  CUMPLE_CON_DQO          3493 non-null   object
#  42  CUMPLE_CON_SST          3493 non-null   object
#  43  CUMPLE_CON_CF           3493 non-null   object
#  44  CUMPLE_CON_E_COLI       3493 non-null   object
#  45  CUMPLE_CON_ENTEROC      3493 non-null   object
#  46  CUMPLE_CON_OD           3493 non-null   object
#  47  CUMPLE_CON_TOX          3493 non-null   object
#  48  GRUPO                   3493 non-null   object
# dtypes: float64(16), object(33)
# memory usage: 1.3+ MB

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(data.corr(), annot=True, cmap='Dark2_r', linewidths = 2)
plt.show()

# %%
data.fillna(method='bfill')
# Out:
#                                                          SITIO  \
# CLAVE
# DLAGU8       PRESA EL SAUCILLO 100M AGUAS ARRIBA DE LA CORTINA
# DLBAJ100                            LOS CABOS SEG 22, 2 ISA10B
# DLBAJ101                            LOS CABOS SEG 22, 1 ISA10B
# DLBAJ102                                           LOS CABOS 3
# DLBAJ103                                           LOS CABOS 1
# ...                                                        ...
# OCRBR5207M1                                         EL LAGUITO
# OCRBR5208M1                PUENTE INTERNACIONAL I NUEVO LAREDO
# OCRBR5209M1                          RIO BRAVO FRENTE A COMAPA
# OCRBR5210M1                   RIO BRAVO 8 (PASO DE LOS INDIOS)
# NaN                                                        NaN
#
#                       ORGANISMO_DE_CUENCA               ESTADO  \
# CLAVE
# DLAGU8            LERMA SANTIAGO PACIFICO       AGUASCALIENTES
# DLBAJ100     PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR
# DLBAJ101     PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR
# DLBAJ102     PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR
# DLBAJ103     PENINSULA DE BAJA CALIFORNIA  BAJA CALIFORNIA SUR
# ...                                   ...                  ...
# OCRBR5207M1                     RIO BRAVO           TAMAULIPAS
# OCRBR5208M1                     RIO BRAVO           TAMAULIPAS
# OCRBR5209M1                     RIO BRAVO           TAMAULIPAS
# OCRBR5210M1                     RIO BRAVO           TAMAULIPAS
# NaN                                   NaN                  NaN
#
#                    MUNICIPIO             CUENCA     CUERPO DE AGUA     TIPO  \
# CLAVE
# DLAGU8       RINCON DE ROMOS      RIO SAN PEDRO  PRESA EL SAUCILLO  LENTICO
# DLBAJ100           LOS CABOS  SAN JOSE DEL CABO    OCEANO PACIFICO  COSTERO
# DLBAJ101           LOS CABOS          SAN LUCAS    OCEANO PACIFICO  COSTERO
# DLBAJ102           LOS CABOS          SAN LUCAS    BAHIA SAN LUCAS  COSTERO
# DLBAJ103           LOS CABOS          SAN LUCAS    BAHIA SAN LUCAS  COSTERO
# ...                      ...                ...                ...      ...
# OCRBR5207M1     NUEVO LAREDO       RIO BRAVO 11         EL LAGUITO  LENTICO
# OCRBR5208M1     NUEVO LAREDO       RIO BRAVO 11          RIO BRAVO   LOTICO
# OCRBR5209M1     NUEVO LAREDO       RIO BRAVO 10          RIO BRAVO   LOTICO
# OCRBR5210M1     NUEVO LAREDO       RIO BRAVO 10          RIO BRAVO   LOTICO
# NaN                      NaN                NaN                NaN      NaN
#
#                 SUBTIPO   LONGITUD   LATITUD  ...  CONTAMINANTES  \
# CLAVE                                         ...
# DLAGU8            PRESA -102.33911  22.24730  ...        DQO,CF,
# DLBAJ100     OCEANO-MAR -109.84290  22.90473  ...  ENT_FEC,OD%F,
# DLBAJ101     OCEANO-MAR -109.86442  22.89880  ...  ENT_FEC,OD%F,
# DLBAJ102          BAHIA -109.88604  22.89609  ...  ENT_FEC,OD%F,
# DLBAJ103          BAHIA -109.89657  22.87694  ...  ENT_FEC,OD%F,
# ...                 ...        ...       ...  ...            ...
# OCRBR5207M1        LAGO  -99.53064  27.43714  ...    DBO,DQO,CF,
# OCRBR5208M1         RIO  -99.50727  27.49901  ...           DQO,
# OCRBR5209M1         RIO  -99.52221  27.49631  ...            CF,
# OCRBR5210M1         RIO  -99.52572  27.51697  ...            CF,
# NaN                 NaN        NaN       NaN  ...            NaN
#
#             CUMPLE_CON_DBO  CUMPLE_CON_DQO CUMPLE_CON_SST  CUMPLE_CON_CF  \
# CLAVE
# DLAGU8                  SI              NO             SI             NO
# DLBAJ100                ND              ND             SI             ND
# DLBAJ101                ND              ND             SI             ND
# DLBAJ102                ND              ND             SI             ND
# DLBAJ103                ND              ND             SI             ND
# ...                    ...             ...            ...            ...
# OCRBR5207M1             NO              NO             SI             NO
# OCRBR5208M1             SI              NO             SI             SI
# OCRBR5209M1             SI              SI             SI             NO
# OCRBR5210M1             SI              SI             SI             NO
# NaN                    NaN             NaN            NaN            NaN
#
#             CUMPLE_CON_E_COLI  CUMPLE_CON_ENTEROC CUMPLE_CON_OD  \
# CLAVE
# DLAGU8                     SI                  ND            SI
# DLBAJ100                   ND                  SI            SI
# DLBAJ101                   ND                  SI            SI
# DLBAJ102                   ND                  SI            SI
# DLBAJ103                   ND                  SI            SI
# ...                       ...                 ...           ...
# OCRBR5207M1                SI                  ND            SI
# OCRBR5208M1                SI                  ND            SI
# OCRBR5209M1                SI                  ND            SI
# OCRBR5210M1                SI                  ND            SI
# NaN                       NaN                 NaN           NaN
#
#              CUMPLE_CON_TOX    GRUPO
# CLAVE
# DLAGU8                   SI  LENTICO
# DLBAJ100                 SI  COSTERO
# DLBAJ101                 SI  COSTERO
# DLBAJ102                 SI  COSTERO
# DLBAJ103                 SI  COSTERO
# ...                     ...      ...
# OCRBR5207M1              SI  LENTICO
# OCRBR5208M1              SI   LOTICO
# OCRBR5209M1              SI   LOTICO
# OCRBR5210M1              SI   LOTICO
# NaN                     NaN      NaN
#
# [3494 rows x 49 columns]

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(data.corr(), annot=True, cmap='Dark2_r', linewidths = 2)
plt.show()

# %%
data = data.dropna(thresh=20)

# %%
#data.hist(columns=['SEMAFORO'])

# %%
data.isna().sum()
# Out:
# SITIO                        0
# ORGANISMO_DE_CUENCA          0
# ESTADO                       0
# MUNICIPIO                    0
# CUENCA                       1
# CUERPO DE AGUA              14
# TIPO                         0
# SUBTIPO                     14
# LONGITUD                     0
# LATITUD                      0
# DBO_mg/L                   912
# CALIDAD_DBO                912
# DQO_mg/L                   912
# CALIDAD_DQO                912
# SST_mg/L                     4
# CALIDAD_SST                  4
# COLI_FEC_NMP_100mL         911
# CALIDAD_COLI_FEC           911
# E_COLI_NMP_100mL           911
# CALIDAD_E_COLI             911
# ENTEROC_NMP_100mL         2589
# CALIDAD_ENTEROC           2589
# OD_PORC                   1696
# CALIDAD_OD_PORC           1696
# OD_PORC_SUP               1874
# CALIDAD_OD_PORC_SUP       1874
# OD_PORC_MED               3006
# CALIDAD_OD_PORC_MED       3006
# OD_PORC_FON               2547
# CALIDAD_OD_PORC_FON       2547
# TOX_D_48_UT               1677
# CALIDAD_TOX_D_48          1677
# TOX_V_15_UT               1674
# CALIDAD_TOX_V_15          1674
# TOX_D_48_SUP_UT           2731
# CALIDAD TOX_D_48_SUP      2731
# TOX_FIS_SUP_15_UT         1819
# CALIDAD_TOX_FIS_SUP_15    1819
# SEMAFORO                     0
# CONTAMINANTES             1267
# CUMPLE_CON_DBO               0
# CUMPLE_CON_DQO               0
# CUMPLE_CON_SST               0
# CUMPLE_CON_CF                0
# CUMPLE_CON_E_COLI            0
# CUMPLE_CON_ENTEROC           0
# CUMPLE_CON_OD                0
# CUMPLE_CON_TOX               0
# GRUPO                        0
# dtype: int64

# %%
data['SST_mg/L']
# Out:
# CLAVE
# DLAGU8          13.7500
# DLBAJ100         9.0000
# DLBAJ101         9.0000
# DLBAJ102        13.9667
# DLBAJ103         9.0000
#                  ...
# OCRBR5206M1    122.0000
# OCRBR5207M1     54.0000
# OCRBR5208M1     70.0000
# OCRBR5209M1     56.0000
# OCRBR5210M1     45.0000
# Name: SST_mg/L, Length: 3493, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

num_transformer = Pipeline(steps= [('MS', MinMaxScaler(feature_range=(1,2)))])
preprocessor = ColumnTransformer(transformers= [('numerical', num_transformer, numeric_features),                                                
                                                ],remainder='passthrough')
data_transform = preprocessor.fit_transform(data[numeric_features])
processed_df = pd.DataFrame(data_transform, columns=preprocessor.feature_names_in_)
processed_df.boxplot(column=numeric_features, figsize=(12,12), rot=45)
# Out:
# <AxesSubplot: >

# %% [markdown]
# **Análisis de clusters con Kmeans**

# %%
df = data[['LATITUD','LONGITUD','SEMAFORO']]
df = df.dropna()
df['SEMAFORO'] = df['SEMAFORO'].replace({'Verde':1,'Amarillo':2,'Rojo':3})
df.head()
# Out:
#            LATITUD   LONGITUD  SEMAFORO
# CLAVE
# DLAGU8    22.24730 -102.33911         3
# DLBAJ100  22.90473 -109.84290         1
# DLBAJ101  22.89880 -109.86442         1
# DLBAJ102  22.89609 -109.88604         1
# DLBAJ103  22.87694 -109.89657         1

# %%
df["Coordinates"] = list(zip(df.LONGITUD, df.LATITUD))
df["Coordinates"] = df["Coordinates"].apply(Point)
df.head()
# Out:
#            LATITUD   LONGITUD  SEMAFORO                  Coordinates
# CLAVE
# DLAGU8    22.24730 -102.33911         3   POINT (-102.33911 22.2473)
# DLBAJ100  22.90473 -109.84290         1   POINT (-109.8429 22.90473)
# DLBAJ101  22.89880 -109.86442         1   POINT (-109.86442 22.8988)
# DLBAJ102  22.89609 -109.88604         1  POINT (-109.88604 22.89609)
# DLBAJ103  22.87694 -109.89657         1  POINT (-109.89657 22.87694)

# %%
gdf = gpd.GeoDataFrame(df, geometry="Coordinates")
gdf.head()
# Out:
#            LATITUD   LONGITUD  SEMAFORO                  Coordinates
# CLAVE
# DLAGU8    22.24730 -102.33911         3  POINT (-102.33911 22.24730)
# DLBAJ100  22.90473 -109.84290         1  POINT (-109.84290 22.90473)
# DLBAJ101  22.89880 -109.86442         1  POINT (-109.86442 22.89880)
# DLBAJ102  22.89609 -109.88604         1  POINT (-109.88604 22.89609)
# DLBAJ103  22.87694 -109.89657         1  POINT (-109.89657 22.87694)

# %%
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
world = world.set_index("iso_a3")

world.head()
# Out:
#             pop_est      continent                      name  gdp_md_est  \
# iso_a3
# FJI        889953.0        Oceania                      Fiji        5496
# TZA      58005463.0         Africa                  Tanzania       63177
# ESH        603253.0         Africa                 W. Sahara         907
# CAN      37589262.0  North America                    Canada     1736425
# USA     328239523.0  North America  United States of America    21433226
#
#                                                  geometry
# iso_a3
# FJI     MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# TZA     POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# ESH     POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# CAN     MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# USA     MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
fig, gax = plt.subplots(figsize=(10,10))
world.query("name == 'Mexico'").plot(ax=gax, edgecolor='black',color='white')
gdf.plot(ax=gax, color='blue', alpha = 0.5)
gax.set_xlabel('LONGITUD')
gax.set_ylabel('LATITUD')
gax.set_title('SEMAFORO')
gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)
plt.show()

# %%
clusters = range(2,15)
inertias = [] 
labels = []
for k in clusters:
    m = KMeans(n_clusters=k)
    m.fit(gdf[["LONGITUD","LATITUD"]])
    labels.append(m.labels_)
    inertias.append(m.inertia_)

# %%
plt.plot(clusters, inertias, 'bo-', markersize=8)
plt.show()

# %%
from sklearn.metrics import silhouette_score
ss = []
for l in labels:
    ss.append(silhouette_score(gdf[["LONGITUD","LATITUD"]], labels=l))

# %%
plt.plot(clusters,ss)

# %%
# Optimal clusters
kmodel = KMeans(n_clusters=7)
kmodel.fit(gdf[["LONGITUD","LATITUD"]])
centroids = kmodel.cluster_centers_
centroids
# Out:
# array([[ -99.25496834,   24.47451469],
#        [-108.76172448,   26.19367705],
#        [ -93.54548215,   17.02616961],
#        [-103.43744637,   20.60943368],
#        [ -98.63222872,   18.88753532],
#        [-115.73931331,   31.72983835],
#        [ -88.12757743,   20.19476814]])

# %%
cdf = pd.DataFrame()
centroids_list = centroids.tolist()
list_of_tuples = [tuple(l) for l in centroids_list]
cdf['latlong'] = list_of_tuples
cdf['c_latlong'] = cdf['latlong'].apply(Point)
cdf2 = gpd.GeoDataFrame(cdf,geometry="c_latlong")

# %%
fig, gax = plt.subplots(figsize=(10,10))
world.query("name == 'Mexico'").plot(ax=gax, edgecolor='black',color='white')
gdf.plot(ax=gax, color='blue', alpha = 0.5)
cdf2.plot(ax=gax, color='red', alpha = 0.7, markersize=100)
gax.set_xlabel('LONGITUD')
gax.set_ylabel('LATITUD')
gax.set_title('SEMAFORO')
gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# **SEGUNDO ENTREGABLE: Clasificación-ensambles y presentación ejecutiva (10 diapositivas max)**

# %%
# Asignacion de variables independientes X y dependiente Y (semáforo)
numeric_features = ['TOX_D_48_UT','TOX_V_15_UT','TOX_D_48_SUP_UT','TOX_FIS_SUP_15_UT','DBO_mg/L','DQO_mg/L','SST_mg/L','OD_PORC','OD_PORC_SUP',
                    'OD_PORC_MED','OD_PORC_FON','COLI_FEC_NMP_100mL','E_COLI_NMP_100mL','ENTEROC_NMP_100mL']
Catego = ['CALIDAD_DBO','CALIDAD_DQO','CALIDAD_SST','CALIDAD_COLI_FEC','CALIDAD_E_COLI','CALIDAD_ENTEROC','CALIDAD_OD_PORC','CALIDAD_OD_PORC_SUP',
           'CALIDAD_OD_PORC_MED','CALIDAD_OD_PORC_FON','CALIDAD_TOX_D_48','CALIDAD_TOX_V_15','CALIDAD TOX_D_48_SUP','CALIDAD_TOX_FIS_SUP_15',
           'CUMPLE_CON_DBO','CUMPLE_CON_DQO','CUMPLE_CON_SST','CUMPLE_CON_CF','CUMPLE_CON_E_COLI','CUMPLE_CON_ENTEROC','CUMPLE_CON_OD','CUMPLE_CON_TOX']

# %%
data['SEMAFORO'] = data['SEMAFORO'].replace({'Verde':1,'Amarillo':2,'Rojo':3})

# %%
X=data.loc[:,numeric_features]
Y= data.loc[:,['SEMAFORO']]

# %%
X.columns
# Out:
# Index(['TOX_D_48_UT', 'TOX_V_15_UT', 'TOX_D_48_SUP_UT', 'TOX_FIS_SUP_15_UT',
#        'DBO_mg/L', 'DQO_mg/L', 'SST_mg/L', 'OD_PORC', 'OD_PORC_SUP',
#        'OD_PORC_MED', 'OD_PORC_FON', 'COLI_FEC_NMP_100mL', 'E_COLI_NMP_100mL',
#        'ENTEROC_NMP_100mL'],
#       dtype='object')

# %%
Xtv, Xtest, ytv, ytest = train_test_split(X, Y, test_size=0.15)
print(Xtv.shape, ': dimensión de datos de entrada para entrenamiento y validación')
print(Xtest.shape, ': dimensión de datos de entrada para prueba')  

print(ytv.shape, ': dimensión de variable de salida para entrenamiento y validación')
print(ytest.shape, ': dimensión de variable de salida para prueba')
# Out:
# (2969, 14) : dimensión de datos de entrada para entrenamiento y validación
# (524, 14) : dimensión de datos de entrada para prueba
# (2969, 1) : dimensión de variable de salida para entrenamiento y validación
# (524, 1) : dimensión de variable de salida para prueba

# %%
num_pipeline = Pipeline(steps = [('impMediana', SimpleImputer(strategy='median')),
                                 ('escalaNum', MinMaxScaler(feature_range=(1,2)))])   
num_pipeline_nombres = numeric_features

# Conjuntamos las transformaciones numéricas y categóricas que se estarán aplicando a los datos de entrada:
columnasTransformer = ColumnTransformer(transformers = [('numpipe', num_pipeline, num_pipeline_nombres)],
                                        remainder='passthrough')

# %%
modeloDummy = DummyClassifier(strategy='stratified')
pipeline = Pipeline(steps=[('ct',columnasTransformer),('m',modeloDummy)])
y_predicciones = TransformedTargetRegressor ( regressor = pipeline)

# %%
def get_models():
  modelos = list()
  nombres = list()

  # LR - Regresión Logística:
  modelos.append(LogisticRegression(solver='liblinear'))
  nombres.append('Logistc Regression')

  # DT - Árbol de Decisión:
  modelos.append(DecisionTreeClassifier())
  nombres.append('Decision Tree')
  
  # MLP - bosque aleatorio:
  modelos.append(RandomForestClassifier(n_estimators=100))
  nombres.append('Random Forest')
  
  
  return modelos, nombres

# %%
modelos, nombres = get_models()  # cargamos los modelos a comparar
resultados = list()   

for i in range(len(modelos)):

  pipeline = Pipeline(steps=[('ct',columnasTransformer),('m',modelos[i])])

  predictions = cross_val_predict(pipeline, Xtv, np.ravel(ytv), cv=3)

  resultados.append(classification_report(np.ravel(ytv), predictions,output_dict=True))
  print ('MODELO: ',nombres [i])
  print(classification_report(np.ravel(ytv), predictions))
# Out:
# MODELO:  Logistc Regression
#               precision    recall  f1-score   support
#
#            1       0.56      0.70      0.62      1075
#            2       0.52      0.48      0.50       974
#            3       0.69      0.54      0.61       920
#
#     accuracy                           0.58      2969
#    macro avg       0.59      0.57      0.57      2969
# weighted avg       0.59      0.58      0.58      2969
#
# MODELO:  Decision Tree
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1075
#            2       0.99      0.99      0.99       974
#            3       1.00      0.99      1.00       920
#
#     accuracy                           0.99      2969
#    macro avg       0.99      0.99      0.99      2969
# weighted avg       0.99      0.99      0.99      2969
#
# MODELO:  Random Forest
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.99      1075
#            2       0.99      0.98      0.98       974
#            3       1.00      0.99      0.99       920
#
#     accuracy                           0.99      2969
#    macro avg       0.99      0.99      0.99      2969
# weighted avg       0.99      0.99      0.99      2969

# %%
delta_C = np.linspace(1, 20, 20)
modelo = DecisionTreeClassifier()
Xx = columnasTransformer.fit_transform(Xtv)
cvLC = RepeatedStratifiedKFold(n_splits=10, n_repeats=5, random_state=11)
train_scores, valid_scores = validation_curve(modelo, 
                                              Xx, 
                                              np.ravel(ytv), 
                                              param_name="max_depth", 
                                              param_range=delta_C,
                                              cv=cvLC,
                                              scoring='accuracy')


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
valid_mean = np.mean(valid_scores, axis=1)
valid_std = np.std(valid_scores, axis=1)


# Curva de entrenamiento con la métrica de exactitud (accuracy):
plt.plot(delta_C, train_mean, color='blue', marker='o', markersize=5, label='Training')

# Curva de validación:
plt.plot(delta_C, valid_mean, color='red', marker='o', markersize=5, label='Validation')

plt.title('Función validation_curve()')
plt.xlabel('Valores del parámetro max depth')
plt.ylabel('Precision')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
modelo = DecisionTreeClassifier()
dicc_grid = {'ccp_alpha':[0.0],'criterion': ['gini', 'entropy'], 'max_depth':[None], 'min_samples_split':[2], 'class_weight':['balanced', None]}
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=5, random_state=8)

grid = GridSearchCV(estimator=modelo, 
                    param_grid=dicc_grid, 
                    cv=cv, 
                    scoring= make_scorer(accuracy_score))

# %%
Xx = columnasTransformer.fit_transform(Xtv)

grid.fit(Xx, np.ravel(ytv))

print('Mejor valor de exactitud obtenido con la mejor combinación:', grid.best_score_)
print('Mejor combinación de valores encontrados de los hiperparámetros:', grid.best_params_)
print('Métrica utilizada:', grid.scoring)
# Out:
# Mejor valor de exactitud obtenido con la mejor combinación: 0.99259009009009
# Mejor combinación de valores encontrados de los hiperparámetros: {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 2}
# Métrica utilizada: make_scorer(accuracy_score)

# %%
modelo = DecisionTreeClassifier (ccp_alpha= 0.0, 
                            class_weight=None,
                            criterion ='entropy',
                            max_depth = None,
                            min_samples_split = 2,
                            random_state=1)

Xct = columnasTransformer.fit(Xtv)
Xxt = Xct.transform(Xtv)
dt_classifier = modelo.fit(Xxt, np.ravel(ytv))

Xxtest = Xct.transform(Xtest)
y_predicciones = dt_classifier.predict(Xxtest)
print(f'Desempeño del modelo utilizando la métrica precision: {accuracy_score(ytest, y_predicciones)}' )
# Out:
# Desempeño del modelo utilizando la métrica precision: 0.9923664122137404

# %%
dot_data = tree.export_graphviz(decision_tree=dt_classifier, 
                                out_file=None,
                                max_depth=None,
                                feature_names=None,
                                class_names=['SEMAFORO 1', 'SEMAFORO 2', 'SEMAFORO 3'],
                                filled=True,
                                rotate=True,
                                proportion=False)

graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
plt.barh(Xtv.columns, dt_classifier.feature_importances_)
# Out:
# <BarContainer object of 14 artists>
